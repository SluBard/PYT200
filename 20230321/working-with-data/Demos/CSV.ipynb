# %% [markdown]
# ## Reading with reader()

# %%
import csv

with open('../csvs/us-population-2010-2014.csv', newline='') as csvfile:
    pops = csv.reader(csvfile) 
    for i, row in enumerate(pops, 1):
        print(', '.join(row))
        if i >= 5:
            break
# Out:
# SEX, AGE, POPESTIMATE2010, POPESTIMATE2011, POPESTIMATE2012, POPESTIMATE2013, POPESTIMATE2014
# A, 0, 3,951,330, 3,963,071, 3,926,665, 3,945,610, 3,948,350
# A, 1, 3,957,888, 3,966,510, 3,978,006, 3,943,077, 3,962,123
# A, 2, 4,090,862, 3,971,573, 3,979,952, 3,992,690, 3,957,772
# A, 3, 4,111,920, 4,102,501, 3,983,049, 3,992,425, 4,005,190

# %% [markdown]
# ## Reading with DictReader()

# %%
import csv

sexes = {'A':'Both', 'M':'Male', 'F':'Female'}

with open('../csvs/us-population-2010-2014.csv', newline='') as csvfile:
    pops = csv.DictReader(csvfile)
    
    header = ','.join(pops.fieldnames)
    print(header)

    print('-' * len(header))
        
    for row in pops:
        sex = sexes[row['SEX']]
        print(sex,
              row['AGE'],
              row['POPESTIMATE2010'],
              row['POPESTIMATE2011'],
              row['POPESTIMATE2012'],
              row['POPESTIMATE2013'],
              row['POPESTIMATE2014'])
# Out:
# SEX,AGE,POPESTIMATE2010,POPESTIMATE2011,POPESTIMATE2012,POPESTIMATE2013,POPESTIMATE2014
# ---------------------------------------------------------------------------------------
# Both 0 3,951,330 3,963,071 3,926,665 3,945,610 3,948,350
# Both 1 3,957,888 3,966,510 3,978,006 3,943,077 3,962,123
# Both 2 4,090,862 3,971,573 3,979,952 3,992,690 3,957,772
# Both 3 4,111,920 4,102,501 3,983,049 3,992,425 4,005,190
# Both 4 4,077,552 4,122,303 4,112,638 3,994,047 4,003,448
# Both 5 4,064,653 4,087,713 4,132,210 4,123,408 4,004,858
# Both 6 4,073,013 4,074,979 4,097,780 4,143,094 4,134,352
# Both 7 4,043,047 4,083,240 4,084,964 4,108,615 4,154,000
# Both 8 4,025,604 4,053,206 4,093,213 4,095,827 4,119,524
# Both 9 4,125,415 4,035,769 4,063,193 4,104,133 4,106,832
# Both 10 4,187,063 4,135,617 4,045,840 4,074,206 4,115,254
# Both 11 4,115,511 4,197,472 4,145,919 4,057,128 4,085,636
# Both 12 4,113,280 4,126,168 4,208,013 4,157,449 4,068,790
# Both 13 4,119,666 4,124,244 4,136,951 4,219,776 4,169,346
# Both 14 4,145,614 4,131,487 4,135,749 4,149,559 4,232,480
# Both 15 4,231,003 4,158,977 4,144,326 4,149,781 4,163,723
# Both 16 4,313,252 4,247,472 4,174,855 4,161,624 4,167,234
# Both 17 4,376,368 4,334,957 4,268,503 4,197,758 4,184,706
# Both 18 4,491,005 4,402,634 4,360,345 4,296,134 4,225,590
# Both 19 4,571,385 4,520,683 4,430,960 4,390,087 4,326,394
# Both 20 4,568,470 4,600,421 4,550,552 4,459,958 4,418,887
# Both 21 4,387,914 4,596,145 4,633,178 4,580,949 4,489,746
# Both 22 4,286,987 4,415,297 4,628,678 4,666,392 4,612,322
# Both 65 2,678,532 2,675,970 3,574,806 3,388,166 3,384,449
# Both 66 2,621,346 2,646,389 2,644,091 3,531,557 3,347,776
# Both 67 2,693,709 2,586,335 2,612,156 2,609,726 3,485,502
# Both 68 2,359,819 2,654,140 2,548,804 2,574,784 2,572,527
# Both 69 2,167,833 2,321,963 2,612,207 2,508,782 2,535,012
# Both 70 2,062,581 2,129,733 2,282,169 2,567,340 2,466,485
# Both 71 1,953,614 2,023,019 2,090,057 2,239,534 2,519,748
# Both 72 1,883,821 1,912,459 1,981,768 2,047,549 2,194,234
# Both 73 1,750,309 1,840,179 1,869,510 1,937,455 2,002,191
# Both 74 1,685,999 1,705,665 1,794,816 1,823,535 1,890,366
# Both 75 1,631,879 1,638,735 1,659,415 1,746,314 1,774,697
# Both 76 1,481,683 1,581,387 1,589,617 1,609,791 1,694,648
# Both 77 1,449,173 1,430,885 1,529,072 1,537,153 1,557,239
# Both 78 1,402,184 1,394,601 1,378,456 1,473,161 1,481,505
# Both 79 1,354,913 1,343,759 1,338,342 1,322,661 1,414,235
# Both 80 1,319,725 1,292,479 1,283,654 1,278,653 1,264,072
# Both 81 1,212,603 1,252,515 1,228,370 1,219,980 1,216,009
# Both 82 1,158,352 1,143,972 1,183,753 1,160,857 1,153,634
# Both 83 1,081,442 1,085,393 1,073,879 1,111,333 1,090,465
# Both 84 987,026 1,005,439 1,011,221 1,000,403 1,036,186
# Both 85 915,015 909,449 928,851 934,211 924,969
# Both 86 821,550 835,003 832,128 850,026 855,696
# Both 87 721,195 741,557 756,235 753,560 770,685
# Both 88 636,657 643,272 663,894 677,229 675,487
# Both 89 546,193 560,102 568,779 587,159 599,834
# Both 90 448,323 473,899 488,100 496,118 512,845
# Both 91 344,443 382,686 407,002 419,045 426,946
# Both 92 288,841 289,272 323,068 344,040 354,532
# Both 93 219,063 238,069 240,255 268,022 286,333
# Both 94 170,775 176,699 193,908 196,079 218,655
# Both 95 131,077 135,059 140,737 154,790 157,124
# Both 96 97,161 101,256 105,454 109,697 121,184
# Both 97 68,893 73,279 77,180 80,524 83,731
# Both 98 47,037 50,665 54,530 57,453 60,185
# Both 99 32,178 33,641 36,780 39,606 41,828
# Both 100 54,409 57,703 61,845 66,748 72,197
# Male 0 2,018,420 2,028,434 2,007,693 2,015,537 2,017,857
# Male 1 2,020,332 2,025,493 2,035,380 2,015,352 2,023,253
# Male 2 2,088,685 2,026,975 2,032,008 2,042,522 2,022,502
# Male 3 2,101,272 2,094,310 2,032,562 2,038,085 2,048,618
# Male 4 2,084,312 2,106,354 2,099,244 2,037,953 2,043,498
# Male 5 2,076,573 2,089,461 2,111,381 2,104,725 2,043,467
# Male 6 2,079,410 2,081,802 2,094,576 2,116,922 2,110,328
# Male 7 2,063,139 2,084,356 2,086,621 2,099,841 2,122,240
# Male 8 2,054,462 2,067,977 2,089,102 2,091,869 2,105,122
# Male 9 2,107,037 2,059,312 2,072,752 2,094,425 2,097,272
# Male 10 2,142,168 2,111,886 2,064,128 2,078,108 2,099,874
# Female 94 126,947 129,530 140,916 141,196 156,525
# Female 95 99,341 101,448 104,220 113,692 114,300
# Female 96 75,139 77,458 79,997 82,067 89,949
# Female 97 54,118 57,164 59,557 61,693 63,252
# Female 98 37,533 40,110 42,876 44,703 46,536
# Female 99 26,074 27,034 29,321 31,378 32,791
# Female 100 45,058 47,557 50,684 54,379 58,468

# %%
pops.fieldnames
# Out:
# ['SEX',
#  'AGE',
#  'POPESTIMATE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014']

# %% [markdown]
# ## Finding Data in a CSV File

# %%
with open('../csvs/us-population-2010-2014.csv', newline='') as csvfile:
    pops = csv.DictReader(csvfile)
    
    for row in pops:
        if (row['AGE'] == '30' and row['SEX'] == 'F'):
            population = row['POPESTIMATE2011']
            break
    else:
        population = None

population
# Out:
# '2,108,531'

# %% [markdown]
# ### Calling find_pop() Multiple Times

# %%
import csv

def find_pop(pops, age, sex, year):
    for row in pops:
        if (row['AGE'] == str(age) and row['SEX'] == sex):
            return row['POPESTIMATE' + str(year)]
    return None

with open('../csvs/us-population-2010-2014.csv', newline='') as csvfile:
    pops = csv.DictReader(csvfile)
    pop1 = find_pop(pops, 30, 'F', 2011)
    pop2 = find_pop(pops, 30, 'F', 2011)

pop1, pop2
# Out:
# ('2,108,531', None)

# %% [markdown]
# #### Fix 1: Use csvfile.seek(0)

# %%
import csv

def find_pop(pops, age, sex, year):
    for row in pops:
        if (row['AGE'] == str(age) and row['SEX'] == sex):
            return row['POPESTIMATE' + str(year)]
    return None

with open('../csvs/us-population-2010-2014.csv', newline='') as csvfile:
    pops = csv.DictReader(csvfile)
    pop1 = find_pop(pops, 30, 'F', 2011)
    csvfile.seek(0)
    pop2 = find_pop(pops, 30, 'F', 2011)

pop1, pop2
# Out:
# ('2,108,531', '2,108,531')

# %% [markdown]
# #### Fix 2: Create a List from csv.DictReader

# %%
import csv

def find_pop(pops, age, sex, year):
    for row in pops:
        if (row['AGE'] == str(age) and row['SEX'] == sex):
            return row['POPESTIMATE' + str(year)]
    return None

with open('../csvs/us-population-2010-2014.csv', newline='') as csvfile:
    pops = list(csv.DictReader(csvfile))

pop1 = find_pop(pops, 30, 'F', 2011)
pop2 = find_pop(pops, 30, 'M', 2011)

pop1, pop2
# Out:
# ('2,108,531', '2,118,884')

# %% [markdown]
# ## Writing with writer()

# %%
import pymysql, csv
connection = pymysql.connect(host='192.185.104.211',
                             user='admin2_student',
                             password='PythonRocks2023!',
                             database='admin2_baseball'
                            )

query = '''SELECT year(debut) year, avg(weight) weight
FROM Master
WHERE debut is NOT NULL
GROUP BY year(debut)
ORDER BY year(debut)'''
    
with connection.cursor() as cursor:
    cursor.execute(query)
    results = cursor.fetchall()
    
connection.close()
print(results)
with open('../csvs/mlb-weight-over-time.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['
, Decimal('186.7233')), (1978, Decimal('186.2297')), (1979, Decimal('187.3659')), (1980, Decimal('186.9379')), (1981, Decimal('186.2740')), (1982, Decimal('189.0141')), (1983, Decimal('189.5000')), (1984, Decimal('187.0758')), (1985, Decimal('187.3360')), (1986, Decimal('186.8537')), (1987, Decimal('185.4645')), (1988, Decimal('190.8794')), (1989, Decimal('188.2467')), (1990, Decimal('188.0828')), (1991, Decimal('191.9531')), (1992, Decimal('191.6049')), (1993, Decimal('192.5567')), (1994, Decimal('193.0877')), (1995, Decimal('192.3077')), (1996, Decimal('196.1907')), (1997, Decimal('195.0889')), (1998, Decimal('198.2115')), (1999, Decimal('198.7667')), (2000, Decimal('198.7598')), (2001, Decimal('202.2915')), (2002, Decimal('206.1618')), (2003, Decimal('201.5110')), (2004, Decimal('204.9663')), (2005, Decimal('210.1650')), (2006, Decimal('209.5611')), (2007, Decimal('209.9194')), (2008, Decimal('207.7143') ...

# %% [markdown]
# ## Writing with DictWriter()

# %%
import pymysql, csv
connection = pymysql.connect(host='192.185.104.211',
                             user='admin2_student',
                             password='PythonRocks2023!',
                             database='admin2_baseball',
                             cursorclass=pymysql.cursors.DictCursor
                            )
query = '''SELECT year(debut) year, avg(weight) weight
FROM Master
WHERE debut is NOT NULL
GROUP BY year(debut)
ORDER BY year(debut)'''
    
with connection.cursor() as cursor:
    cursor.execute(query)
    results = cursor.fetchall()
    
connection.close()
print(results)
with open('../csvs/mlb-weight-over-time2.csv', 'w', newline='') as csvfile:
    fieldnames = results[0].keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(results)
# Out:
# [{'year': 1871, 'weight': Decimal('157.0495')}, {'year': 1872, 'weight': Decimal('166.9032')}, {'year': 1873, 'weight': Decimal('157.5385')}, {'year': 1874, 'weight': Decimal('159.5000')}, {'year': 1875, 'weight': Decimal('164.0408')}, {'year': 1876, 'weight': Decimal('165.9375')}, {'year': 1877, 'weight': Decimal('167.6923')}, {'year': 1878, 'weight': Decimal('172.0667')}, {'year': 1879, 'weight': Decimal('169.0851')}, {'year': 1880, 'weight': Decimal('170.3636')}, {'year': 1881, 'weight': Decimal('173.3333')}, {'year': 1882, 'weight': Decimal('169.3000')}, {'year': 1883, 'weight': Decimal('171.7143')}, {'year': 1884, 'weight': Decimal('167.7733')}, {'year': 1885, 'weight': Decimal('173.6176')}, {'year': 1886, 'weight': Decimal('168.1930')}, {'year': 1887, 'weight': Decimal('165.9538')}, {'year': 1888, 'weight': Decimal('170.9130')}, {'year': 1889, 'weight': Decimal('168.7818')}, {'year': 1890, 'weight': Decimal('169.2973')}, {'year': 1891, 'weight': Decimal('168.9194')}, {'year': 1892, 'weight': Decimal('167.2683')}, {'year': 1893, 'weight': Decimal('173.3878')}, {'year': 1894, 'weight': Decimal('166.2692')}, {'year': 1895, 'weight': Decimal('170.0882')}, {'year': 1896, 'weight': Decimal('169.7241')}, {'year': 1897, 'weight': Decimal('173.5957')}, {'year': 1898, 'weight': Decimal('172.3538')}, {'year': 1899, 'weight': Decimal('170.3824')}, {'year': 1900, 'weight': Decimal('174.5263')}, {'year': 1901, 'weight': Decimal('172.4818')}, {'year': 1902, 'weight': Decimal('173.7788')}, {'year': 1903, 'weight': Decimal('171.6667')}, {'year': 1904, 'weight': Decimal('171.0349')}, {'year': 1905, 'weight': Decimal('176.5500')}, {'year': 1906, 'weight': Decimal('174.9368')}, {'year': 1907, 'weight': Decimal('173.0233')}, {'year': 1908, 'weight': Decimal('174.2035')}, {'year': 1909, 'weight': Decimal('176.2897')}, {'year': 1910, 'weight': Decimal('172.1477')}, {'year': 1911, 'weight': Decimal('172.3925')}, {'year': 1912, 'weight': Decimal('171.3756')}, {'year': 1913, 'weight': Decimal('173.3182')}, {'year': 1914, 'weight': Decimal('171.1542')}, {'year': 1915, 'weight': Decimal('172.6954')}, {'year': 1916, 'weight': Decimal('168.7449')}, {'year': 1917, 'weight': Decimal('169.5870')}, {'year': 1918, 'weight': Decimal('173.4459')}, {'year': 1919, 'weight': Decimal('172.2268')}, {'year': 1920, 'weight': Decimal('172.2000')}, {'year': 1921, 'weight': Decimal('169.4017')}, {'year': 1922, 'weight': Decimal('173.9051')}, {'year': 1923, 'weight': Decimal('173.8784')}, {'year': 1924, 'weight': Decimal('173.1148')}, {'year': 1925, 'weight': Decimal('171.9397')}, {'year': 1926, 'weight': Decimal('173.1875')}, {'year': 1927, 'weight': Decimal('171.5370')}, {'year': 1928, 'weight': Decimal('176.9286')}, {'year': 1929, 'weight': Decimal('174.6881')}, {'year': 1930, 'weight': Decimal('177.3163')}, {'year': 1931, 'weight': Decimal('176.5294')}, {'year': 1932, 'weight': Decimal('176.4409')}, {'year': 1933, 'weight': Decimal('180.2286')}, {'year': 1934, 'weight': Decimal('180.0796')}, {'year': 1935, 'weight': Decimal('178.1652')}, {'year': 1936, 'weight': Decimal('180.4455')}, {'year': 1937, 'weight': Decimal('179.8909')}, {'year': 1938, 'weight': Decimal('178.1560')}, {'year': 1939, 'weight': Decimal('180.5591')}, {'year': 1940, 'weight': Decimal('183.0096')}, {'year': 1941, 'weight': Decimal('183.5333')}, {'year': 1942, 'weight': Decimal('182.6000')}, {'year': 1943, 'weight': Decimal('182.3356')}, {'year': 1944, 'weight': Decimal('180.6078')}, {'year': 1945, 'weight': Decimal('179.8306')}, {'year': 1946, 'weight': Decimal('183.2991')}, {'year': 1947, 'weight': Decimal('182.4898')}, {'year': 1948, 'weight': Decimal('183.4035')}, {'year': 1949, 'weight': Decimal('183.5217')}, {'year': 1950, 'weight': Decimal('183.5238')}, {'year': 1951, 'weight': Decimal('181.5000')}, {'year': 1952, 'weight': Decimal('184.5175')}, {'year': 1953, 'weight': Decimal('184.4800')}, {'year': 1954, 'weight': Decimal('183.1322')}, {'year': 1955, 'weight': Decimal('184.4161')}, {'ye ...

# %% [markdown]
# ## Append to a CSV File

# %%
with open('../csvs/mlb-weight-over-time.csv', 'a', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow([2015,200])

# %% [markdown]
# Source: Vintage 2014 National Population Datasets
#
# https://www.census.gov/popest/data/national/asrh/2014/files/NC-EST2014-AGESEX-RES.csv
