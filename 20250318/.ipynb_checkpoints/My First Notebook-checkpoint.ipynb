# %%
print("hello world")
# Out:
# hello world

# %%
1+1
# Out:
# 2

# %%
result=print("hello world")
print(result)
# Out:
# hello world
# None

# %%
def myprint(text):
    print(text)
    return 'i printed ' + text

# %%
result=myprint("hello world")
print(result)
# Out:
# hello world
# i printed hello world

# %%
i=2
x=4
i,x
# Out:
# (2, 4)

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B832-E9ED
#
#  Directory of C:\Users\cwod_admin\Desktop\PYT200\20250318
#
# 03/18/2025  05:59 PM    <DIR>          .
# 03/18/2025  05:59 PM    <DIR>          ..
# 03/18/2025  05:44 PM    <DIR>          .ipynb_checkpoints
# 03/18/2025  04:54 PM    <DIR>          advanced-python-concepts
# 03/18/2025  04:54 PM    <DIR>          classes-objects
# 03/18/2025  04:52 PM             1,909 create_notebooks.py
# 03/18/2025  04:52 PM             2,540 Find File.ipynb
# 03/18/2025  04:52 PM             1,260 find_file.py
# 03/18/2025  04:54 PM    <DIR>          ipython-notebook
# 03/18/2025  05:59 PM             2,559 My First Notebook.ipynb
# 03/18/2025  04:54 PM    <DIR>          PYT211-exam
# 03/18/2025  04:54 PM    <DIR>          regular-expressions
# 03/18/2025  04:54 PM    <DIR>          testing-debugging
# 03/18/2025  04:54 PM    <DIR>          unicode-encoding
# 03/18/2025  04:54 PM    <DIR>          working-with-data
# ...

# %%
# %cd advanced-python-concepts
# %ls
# %pwd
# Out:
# [WinError 2] The system cannot find the file specified: 'advanced-python-concepts'
# C:\Users\cwod_admin\Desktop\PYT200\20250318\advanced-python-concepts
#  Volume in drive C has no label.
#  Volume Serial Number is B832-E9ED
#
#  Directory of C:\Users\cwod_admin\Desktop\PYT200\20250318\advanced-python-concepts
#
# 03/18/2025  04:54 PM    <DIR>          .
# 03/18/2025  04:54 PM    <DIR>          ..
# 03/18/2025  04:54 PM    <DIR>          Demos
# 03/18/2025  04:54 PM    <DIR>          Exercises
# 03/18/2025  04:54 PM    <DIR>          Solutions
#                0 File(s)              0 bytes
#                5 Dir(s)  19,813,961,728 bytes free
# 'C:\\Users\\cwod_admin\\Desktop\\PYT200\\20250318\\advanced-python-concepts'

# %%
# %bookmark -d here

# %%
# %bookmark -l
# Out:
# Current bookmarks:

# %%
# %history
# Out:
# print("hello world")
# print("hello world")
# load create_notebooks.py
# 1+1
# result=print("hello world")
# print(result)
# def myprint(text):
#     print(text)
#     return 'i printed ' + text
# result=myprint("hello world")
# print(result)
# i=2
# x=4
# i
# i=2
# x=4
# i
# x
# i=2
# x=4
# i,x
# %dir
# %ls
# %automagic
# %automagic on
# %automagic off
# %ls
# %cd advanced-python-concepts
# %ls
# %cd advanced-python-concepts
# %ls
# %pwd
# %bookmark -l
# %bookmark here .
# %bookmark -l
# %cd here
# %bookmark -d here
# %bookmark -l
# %history

# %%
path=%env PATH

# %%
# %env new stuff
# Out:
# env: new=stuff

# %%
# !!ping www.google.com
# Out:
# ['',
#  'Pinging www.google.com [142.250.189.164] with 32 bytes of data:',
#  'Reply from 142.250.189.164: bytes=32 time=20ms TTL=113',
#  'Reply from 142.250.189.164: bytes=32 time=20ms TTL=113',
#  'Reply from 142.250.189.164: bytes=32 time=20ms TTL=113',
#  'Reply from 142.250.189.164: bytes=32 time=20ms TTL=113',
#  '',
#  'Ping statistics for 142.250.189.164:',
#  '    Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),',
#  'Approximate round trip times in milli-seconds:',
#  '    Minimum = 20ms, Maximum = 20ms, Average = 20ms']

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
import math
math??

# %%
help()
# Out:
# Welcome to Python 3.6's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.6/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> math
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
# ...

# %%
import datetime

# %%
help(datetime)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
#      |      Formats self with strftime.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
# ...
