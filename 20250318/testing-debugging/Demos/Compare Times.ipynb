# %%
import time

t1 = time.perf_counter()
t2 = time.perf_counter()
t1, t2, t2-t1
# Out:
# (6e-07, 3.08e-05, 3.0200000000000002e-05)

# %%
import random

start_time = time.perf_counter()
numbers = str(random.randint(1,100))
for i in range(1000):
    num = random.randint(1,100)
    numbers += ',' + str(num)
end_time = time.perf_counter()
td1 = end_time - start_time

start_time = time.perf_counter()
numbers = [str(random.randint(1,100)) for i in range(1,1000)]
numbers = ', '.join(numbers)
end_time = time.perf_counter()
td2 = end_time - start_time

print('''Time Delta 1: {}
Time Delta 2: {}'''.format(td1, td2))
# Out:
# Time Delta 1: 0.003689600000001292
# Time Delta 2: 0.0023275000000069213

# %%
import random

start_time = time.perf_counter()
for j in range(1000):
    numbers = str(random.randint(1,100))
    for i in range(1000):
        num = random.randint(1,100)
        numbers += ',' + str(num)
end_time = time.perf_counter()
td1 = end_time - start_time

start_time = time.perf_counter()
for j in range(1000):
    numbers = [str(random.randint(1,100)) for i in range(1,1000)]
    numbers = ', '.join(numbers)
end_time = time.perf_counter()
td2 = end_time - start_time

print('''Time Delta 1: {}
Time Delta 2: {}'''.format(td1, td2))
# Out:
# Time Delta 1: 1.644682099999983
# Time Delta 2: 1.2247705000000053

# %%
import random
from timeit import timeit

def string_nums1():
    numbers = str(random.randint(1,100))
    for i in range(1000):
        num = random.randint(1,100)
        numbers += ', ' + str(num)
    
def string_nums2():
    numbers = [str(random.randint(1,100)) for i in range(1,1000)]
    numbers = ', '.join(numbers)

td1 = timeit(string_nums1, number=1000)
td2 = timeit(string_nums2, number=1000)

td1, td2
# Out:
# (1.5127180000000067, 1.2390820999999619)

# %%
import random
from timeit import timeit

str_nums1 = """
numbers = str(random.randint(1,100))
for i in range(1000):
    num = random.randint(1,100)
    numbers += ', ' + str(num)"""
    
str_nums2 = """
numbers = [str(random.randint(1,100)) for i in range(1,1000)]
numbers = ', '.join(numbers)"""

td1 = timeit(str_nums1, number=1000, globals=globals())
td2 = timeit(str_nums2, number=1000, globals=globals())

print(td1, td2)
# Out:
# 1.5373481999999967 1.2214208000000326

# %%
from timeit import timeit

str_nums1 = """
numbers = str(random.randint(1,100))
for i in range(1000):
    num = random.randint(1,100)
    numbers += ', ' + str(num)"""
    
str_nums2 = """
numbers = [str(random.randint(1,100)) for i in range(1,1000)]
numbers = ', '.join(numbers)"""

td1 = timeit(str_nums1, number=1000, setup='import random')
td2 = timeit(str_nums2, number=1000, setup='import random')

td1, td2
# Out:
# (1.494114599999989, 1.2210344000000077)

# %%
from timeit import repeat

string_nums1 = """
numbers = str(random.randint(1,100))
for i in range(1000):
    num = random.randint(1,100)
    numbers += ', ' + str(num)"""
    
string_nums2 = """
numbers = [str(random.randint(1,100)) for i in range(1,1000)]
numbers = ', '.join(numbers)"""

tds1 = repeat(string_nums1, number=1000, repeat=4, setup='import random')
tds2 = repeat(string_nums2, number=1000, repeat=4, setup='import random')

tds1, tds2
# Out:
# ([1.4918497999999545,
#   1.4684997000000521,
#   1.4682202999999845,
#   1.4597658000000138],
#  [1.207078700000011,
#   1.201156699999956,
#   1.2077509999999165,
#   1.2076448999999911])

# %%
'{:.2%}'.format(1 - sum(tds2) / sum(tds1))
# Out:
# '18.08%'

# %%
import random

def string_nums1():
    numbers = str(random.randint(1,100))
    for i in range(1000):
        num = random.randint(1,100)
        numbers += ', ' + str(num)
    
def string_nums2():
    numbers = [str(random.randint(1,100)) for i in range(1,1000)]
    numbers = ', '.join(numbers)

tr1 = %timeit -n1000 -r4 -o string_nums1()
tr2 = %timeit -n1000 -r4 -o string_nums2()
# Out:
# 1.47 ms ± 16 µs per loop (mean ± std. dev. of 4 runs, 1000 loops each)
# 1.22 ms ± 16.9 µs per loop (mean ± std. dev. of 4 runs, 1000 loops each)

# %%
tr1.all_runs
# Out:
# [1.4969246000000567,
#  1.4618089999999029,
#  1.4628682999999683,
#  1.4567164999999704]

# %%
'{:.2%}'.format(1 - sum(tr2.all_runs) / sum(tr1.all_runs) )
# Out:
# '17.10%'

# %%
# %%timeit -n 1000

numbers = str(random.randint(1,100))
for i in range(1000):
    num = random.randint(1,100)
    numbers += ', ' + str(num)
# Out:
# 1.49 ms ± 14.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit -n 1000

numbers = [str(random.randint(1,100)) for i in range(1,1000)]
numbers = ', '.join(numbers)
# Out:
# 1.26 ms ± 30.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
