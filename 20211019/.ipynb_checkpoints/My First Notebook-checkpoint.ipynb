# %% [markdown]
# # Heading 1

# %%
result = print("Hello World!")
print(result)

# %%
def my_print(text):
    print(text)
    return 'I printed '+text

# %%
result = my_print("Hello World!")
print(result)
# Out:
# Hello World!
# I printed Hello World!

# %%
1+1
# Out:
# 2

# %%
# %automagic
# Out:
# Automagic is OFF, % prefix IS needed for line magics.

# %%
# %pwd
# Out:
# 'C:\\Users\\cwod_admin\\ClassFiles'

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B832-E9ED
#
#  Directory of C:\Users\cwod_admin\ClassFiles
#
# 10/19/2021  06:07 PM    <DIR>          .
# 10/19/2021  06:07 PM    <DIR>          ..
# 10/19/2021  05:53 PM    <DIR>          .ipynb_checkpoints
# 08/09/2018  03:58 PM    <DIR>          advanced-python-concepts
# 08/09/2018  03:58 PM    <DIR>          classes-objects
# 08/09/2018  04:03 PM             1,909 create_notebooks.py
# 08/09/2018  04:03 PM             2,450 Find File.ipynb
# 08/09/2018  04:03 PM             1,223 find_file.py
# 08/09/2018  03:58 PM    <DIR>          ipython-notebook
# 10/19/2021  06:07 PM             3,389 My First Notebook.ipynb
# 08/09/2018  03:58 PM    <DIR>          PYT211-exam
# 08/09/2018  03:58 PM    <DIR>          regular-expressions
# 08/09/2018  03:58 PM    <DIR>          testing-debugging
# 08/09/2018  03:58 PM    <DIR>          unicode-encoding
# 08/09/2018  03:58 PM    <DIR>          working-with-data
# ...

# %%
# %cd advanced-python-concepts
# Out:
# C:\Users\cwod_admin\ClassFiles\advanced-python-concepts

# %%
# %bookmark advanced-python

# %%
# %bookmark -l
# Out:
# Current bookmarks:
# advanced-python -> C:\Users\cwod_admin\ClassFiles\advanced-python-concepts

# %%
# %cd
# Out:
# C:\Users\cwod_admin

# %%
# %cd advanced-python
# Out:
# (bookmark:advanced-python) -> C:\Users\cwod_admin\ClassFiles\advanced-python-concepts
# C:\Users\cwod_admin\ClassFiles\advanced-python-concepts

# %%
# %history
# Out:
# %automagic
# %dir
# %ls
# %pwd
# %ls
# %cd advanced-python-concepts
# %bookmark advanced-python
# %bookmark -l
# %cd
# %pwd
# %cd advanced-python
# %history

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\cwod_admin\\AppData\\Roaming',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'ADVPYTHON',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': 'C:\\ProgramData\\Anaconda3\\Scripts\\conda.exe',
#  'CONDA_PREFIX': 'C:\\ProgramData\\Anaconda3',
#  'CONDA_PROMPT_MODIFIER': '(base) ',
#  'CONDA_PYTHON_EXE': 'C:\\ProgramData\\Anaconda3\\python.exe',
#  'CONDA_SHLVL': '1',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'FP_NO_HOST_CHECK': 'NO',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\cwod_admin',
#  'JAVA_HOME': 'C:\\Program Files\\Java\\jdk1.8.0_45',
#  'LOCALAPPDATA': 'C:\\Users\\cwod_admin\\AppData\\Local',
#  'LOGONSERVER': '\\\\ADVPYTHON',
#  'NUMBER_OF_PROCESSORS': '2',
# ...

# %%
path =%env PATH

# %%
path
# Out:
# 'C:\\ProgramData\\Anaconda3;C:\\ProgramData\\Anaconda3\\Library\\mingw-w64\\bin;C:\\ProgramData\\Anaconda3\\Library\\usr\\bin;C:\\ProgramData\\Anaconda3\\Library\\bin;C:\\ProgramData\\Anaconda3\\Scripts;C:\\ProgramData\\Anaconda3\\bin;C:\\ProgramData\\Anaconda3\\condabin;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\ProgramData\\Anaconda3;C:\\Users\\cwod_admin\\AppData\\Local\\Microsoft\\WindowsApps;.'

# %%
path2 = path.split(';')
for i in path2:
    print(i)
# Out:
# C:\ProgramData\Anaconda3
# C:\ProgramData\Anaconda3\Library\mingw-w64\bin
# C:\ProgramData\Anaconda3\Library\usr\bin
# C:\ProgramData\Anaconda3\Library\bin
# C:\ProgramData\Anaconda3\Scripts
# C:\ProgramData\Anaconda3\bin
# C:\ProgramData\Anaconda3\condabin
# C:\WINDOWS\system32
# C:\WINDOWS
# C:\WINDOWS\System32\Wbem
# C:\WINDOWS\System32\WindowsPowerShell\v1.0
# C:\WINDOWS\System32\WindowsPowerShell\v1.0
# C:\WINDOWS\System32\OpenSSH
# C:\ProgramData\Anaconda3
# C:\Users\cwod_admin\AppData\Local\Microsoft\WindowsApps
# .

# %%
# !!ping www.google.com
# Out:
# ['',
#  'Pinging www.google.com [172.217.3.68] with 32 bytes of data:',
#  'Reply from 172.217.3.68: bytes=32 time=8ms TTL=111',
#  'Reply from 172.217.3.68: bytes=32 time=7ms TTL=111',
#  'Reply from 172.217.3.68: bytes=32 time=7ms TTL=111',
#  'Reply from 172.217.3.68: bytes=32 time=8ms TTL=111',
#  '',
#  'Ping statistics for 172.217.3.68:',
#  '    Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),',
#  'Approximate round trip times in milli-seconds:',
#  '    Minimum = 7ms, Maximum = 8ms, Average = 7ms']

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %quickref

# %%
import datetime
datetime.datetime??

# %%
help(datetime)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
#      |      Formats self with strftime.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __hash__(self, /)
#      |      Return hash(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
# ...
